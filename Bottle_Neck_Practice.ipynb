# %% [markdown]
# <a href="https://colab.research.google.com/github/seunghwan1228/CNN-with-Bottle-Neck/blob/master/Bottle_Neck_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar10
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from keras import models, layers
from keras import optimizers
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from keras import callbacks
from tensorflow import keras

# %%
(X_train, y_train), (X_hold_out, y_hold_out) = cifar10.load_data()

X_train = X_train/255
X_hold_out = X_hold_out/255

y_train = to_categorical(y_train)
y_hold_out = to_categorical(y_hold_out)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
callback = callbacks.EarlyStopping(patience = 10)

# %%
Model = keras.Sequential()
Model.add(keras.layers.Conv2D(32, kernel_size=3, strides=(2,2), padding='same',input_shape=(32,32,3)))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))

Model.add(keras.layers.Conv2D(32, kernel_size=1, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))

Model.add(keras.layers.Conv2D(32, kernel_size=3, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))

Model.add(keras.layers.Conv2D(32, kernel_size=3, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))

Model.add(keras.layers.Conv2D(32, kernel_size=3, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))


Model.add(keras.layers.AvgPool2D(2,2))


Model.add(keras.layers.Conv2D(64, kernel_size=5, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))
Model.add(keras.layers.Conv2D(64, kernel_size=5, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))


Model.add(keras.layers.Conv2D(128, kernel_size=3, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))
Model.add(keras.layers.Conv2D(128, kernel_size=3, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))
Model.add(keras.layers.Conv2D(128, kernel_size=3, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))

Model.add(keras.layers.AvgPool2D(2,2))

Model.add(keras.layers.Conv2D(256, kernel_size=5, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))
Model.add(keras.layers.Conv2D(256, kernel_size=5, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))
Model.add(keras.layers.Conv2D(256, kernel_size=5, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))
Model.add(keras.layers.Conv2D(256, kernel_size=5, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))
Model.add(keras.layers.Conv2D(256, kernel_size=5, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))
Model.add(keras.layers.Conv2D(256, kernel_size=5, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))
Model.add(keras.layers.Conv2D(256, kernel_size=5, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))

Model.add(keras.layers.AvgPool2D(2,2))


Model.add(keras.layers.Conv2D(512, kernel_size=3, strides=(1,1), padding='same'))
Model.add(keras.layers.BatchNormalization())
Model.add(keras.layers.Activation(activation=tf.nn.swish))
Model.add(keras.layers.Dropout(0.5))
Model.add(keras.layers.AvgPool2D(2,2))


Model.add(keras.layers.Flatten())


Model.add(keras.layers.Dense(512, activation ='relu'))
Model.add(keras.layers.Dropout(0.5))

Model.add(keras.layers.Dense(10, activation='softmax'))


Model.summary()


Model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 16, 16, 32)        896
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation (Activation)      (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 32)        1056
# _________________________________________________________________
# batch_normalization_v1_1 (Ba (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 16, 32)        0
# ...

# %%
history = Model.fit(X_train, y_train, epochs=200, validation_data=(X_test, y_test), batch_size=512) # initial trainig
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/200
# 40000/40000 [==============================] - 25s 627us/sample - loss: 2.3517 - acc: 0.1016 - val_loss: 2.3039 - val_acc: 0.0933
# Epoch 2/200
# 40000/40000 [==============================] - 22s 561us/sample - loss: 2.2955 - acc: 0.1104 - val_loss: 2.3035 - val_acc: 0.0994
# Epoch 3/200
# 40000/40000 [==============================] - 22s 558us/sample - loss: 2.2026 - acc: 0.1418 - val_loss: 3.2903 - val_acc: 0.0987
# Epoch 4/200
# 40000/40000 [==============================] - 22s 553us/sample - loss: 1.9341 - acc: 0.2257 - val_loss: 10.2083 - val_acc: 0.1063
# Epoch 5/200
# 40000/40000 [==============================] - 22s 554us/sample - loss: 1.8493 - acc: 0.2688 - val_loss: 4.3994 - val_acc: 0.1429
# Epoch 6/200
# 40000/40000 [==============================] - 22s 555us/sample - loss: 1.7851 - acc: 0.2957 - val_loss: 3.8821 - val_acc: 0.1932
# Epoch 7/200
# ...

# %%
history2 = Model.fit(X_train, y_train, epochs=300, validation_data=(X_test, y_test), batch_size=512) # more training
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/300
# 40000/40000 [==============================] - 22s 556us/sample - loss: 0.6693 - acc: 0.7702 - val_loss: 0.5966 - val_acc: 0.8033
# Epoch 2/300
# 40000/40000 [==============================] - 22s 556us/sample - loss: 0.6746 - acc: 0.7686 - val_loss: 0.6043 - val_acc: 0.8056
# Epoch 3/300
# 40000/40000 [==============================] - 22s 554us/sample - loss: 0.6677 - acc: 0.7717 - val_loss: 0.5849 - val_acc: 0.8076
# Epoch 4/300
# 40000/40000 [==============================] - 22s 554us/sample - loss: 0.6644 - acc: 0.7716 - val_loss: 0.6082 - val_acc: 0.7943
# Epoch 5/300
# 40000/40000 [==============================] - 22s 554us/sample - loss: 0.6638 - acc: 0.7716 - val_loss: 0.6157 - val_acc: 0.7973
# Epoch 6/300
# 40000/40000 [==============================] - 22s 554us/sample - loss: 0.6676 - acc: 0.7691 - val_loss: 0.5912 - val_acc: 0.8031
# Epoch 7/300
# ...

# %%
history3 = Model.fit(X_train, y_train, epochs=300, validation_data=(X_test, y_test), batch_size=512) # more training
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/300
# 40000/40000 [==============================] - 23s 567us/sample - loss: 0.5670 - acc: 0.8013 - val_loss: 0.5645 - val_acc: 0.8201
# Epoch 2/300
# 40000/40000 [==============================] - 22s 558us/sample - loss: 0.5481 - acc: 0.8095 - val_loss: 0.5667 - val_acc: 0.8184
# Epoch 3/300
# 40000/40000 [==============================] - 22s 552us/sample - loss: 0.5389 - acc: 0.8105 - val_loss: 0.5665 - val_acc: 0.8179
# Epoch 4/300
# 40000/40000 [==============================] - 22s 553us/sample - loss: 0.5318 - acc: 0.8147 - val_loss: 0.5737 - val_acc: 0.8173
# Epoch 5/300
# 40000/40000 [==============================] - 22s 555us/sample - loss: 0.5319 - acc: 0.8164 - val_loss: 0.6116 - val_acc: 0.8076
# Epoch 6/300
# 40000/40000 [==============================] - 22s 555us/sample - loss: 0.5352 - acc: 0.8145 - val_loss: 0.5761 - val_acc: 0.8210
# Epoch 7/300
# ...

# %%
history3 = Model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), batch_size=512) # more training
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/100
# 40000/40000 [==============================] - 22s 556us/sample - loss: 0.4426 - acc: 0.8438 - val_loss: 0.6142 - val_acc: 0.8196
# Epoch 2/100
# 40000/40000 [==============================] - 23s 563us/sample - loss: 0.4384 - acc: 0.8448 - val_loss: 0.6223 - val_acc: 0.8174
# Epoch 3/100
# 40000/40000 [==============================] - 22s 555us/sample - loss: 0.4386 - acc: 0.8464 - val_loss: 0.6179 - val_acc: 0.8192
# Epoch 4/100
# 40000/40000 [==============================] - 22s 553us/sample - loss: 0.4428 - acc: 0.8436 - val_loss: 0.6029 - val_acc: 0.8240
# Epoch 5/100
# 40000/40000 [==============================] - 22s 554us/sample - loss: 0.4333 - acc: 0.8462 - val_loss: 0.6172 - val_acc: 0.8222
# Epoch 6/100
# 40000/40000 [==============================] - 22s 555us/sample - loss: 0.4290 - acc: 0.8480 - val_loss: 0.6092 - val_acc: 0.8232
# Epoch 7/100
# ...

# %%
Model.save(filepath='content/cnn_learning2.h5')
